# %%
import ipywidgets as widgets
from IPython.display import display, HTML
javascript_functions = {False: "hide()", True: "show()"}
button_descriptions  = {False: "Show code", True: "Hide code"}
def toggle_code(state):
    output_string = "<script>$(\"div.input\").{}</script>"
    output_args   = (javascript_functions[state],)
    output        = output_string.format(*output_args)
    display(HTML(output))
def button_action(value):
    state = value.new
    toggle_code(state)
    value.owner.description = button_descriptions[state]
state = False
toggle_code(state)
button = widgets.ToggleButton(state, description = button_descriptions[state])
button.observe(button_action, "value")
display(button)
# Out:
# <script>$("div.input").hide()</script>
# ToggleButton(value=False, description='Show code')
# <script>$("div.input").show()</script>

# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
CSS = """#notebook div.output_subarea {max-width:100%;}""" #changes output_subarea width to 100% (from 100% - 14ex)
HTML('<style>{}</style>'.format(CSS))

import ipywidgets as widgets
from IPython.display import display

from numpy import random
import pandas as pd
import math
from pyecharts.charts import Sunburst, Bar, Line, Scatter, Map, Sankey, Geo, Pie, Grid, Page
from pyecharts import options as opts
from pyecharts.globals import ChartType, SymbolType, ThemeType
from pyecharts.render import make_snapshot
from snapshot_phantomjs import snapshot
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>

# %%
path = "D:/CASTED/专利/中间表/zhuanli_reports.xlsx"

# %% [markdown]
# # 一、全国各产业创新现状
# ## 1.1各产业整体数量分布对比（2010-2018年）

# %%
industry_df  = pd.read_excel(path, sheet_name = "十年行业占比饼环图")
industry_df.columns = ["二级分类", "三级分类", "专利数"]

class_df = industry_df.groupby(['二级分类']).sum().reset_index().sort_values(by = ["专利数"], ascending = True)
class_df["百分比"] = (class_df["专利数"] / class_df["专利数"].sum() * 100).round(2)
class_df = class_df.sort_values(by = ["百分比"], ascending = False)

##########################################################################################################
## 绘制专利数种类占比饼图
##########################################################################################################
def pie_radius(class_df) -> Pie:
    
    df = class_df
    
    c = (
        Pie(init_opts=opts.InitOpts())
        .add(
            "",
            [list(z) for z in zip(df["二级分类"].tolist(), df["百分比"].tolist())],
            radius=["30%", "45%"],
            is_clockwise = False, 
            center = ["50%", "50%"]
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="各产业整体数量分布对比（2010-2018年）"),
            legend_opts=opts.LegendOpts(
                orient="vertical", pos_top="15%", pos_left="2%"
            ),
        )
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}%"))
        )
             
    return c

c_classPie = pie_radius(class_df)
c_classPie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="56da0109f0a54dfab79bbe7fc6d4feb9" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_56da0109f0a54dfab79bbe7fc6d4feb9 = echarts.init(
#             document.getElementById('56da0109f0a54dfab79bbe7fc6d4feb9'), 'white', {renderer: 'canvas'});
#         var option_56da0109f0a54dfab79bbe7fc6d4feb9 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": false,
#             "data": [
#                 {
#                     "name": "\u5236\u9020\u4e1a",
#                     "value": 86.1
#                 },
#                 {
#                     "name": "\u5c45\u6c11\u670d\u52a1\u3001\u4fee\u7406\u548c\u5176\u4ed6\u670d\u52a1\u4e1a",
#                     "value": 7.72
#                 },
#                 {
#                     "name": "\u4fe1\u606f\u4f20\u8f93\u3001\u8f6f\u4ef6\u548c\u4fe1\u606f\u6280\u672f\u670d\u52a1\u4e1a",
#                     "value": 2.25
#                 },
#                 {
#                     "name": "\u5efa\u7b51\u4e1a",
#                     "value": 1.6
#                 },
#                 {
#                     "name": "\u7535\u529b\u3001\u70ed\u529b\u3001\u71c3\u6c14\u53ca\u6c34\u751f\u4ea7\u548c\u4f9b\u5e94\u4e1a",
#                     "value": 0.99
#                 },
#                 {
#                     "name": "\u519c\u3001\u6797\u3001\u7267\u3001\u6e14\u4e1a",
#                     "value": 0.67
#                 },
#                 {
#                     "name": "\u91c7\u77ff\u4e1a",
#                     "value": 0.66
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "45%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5236\u9020\u4e1a",
#                 "\u5c45\u6c11\u670d\u52a1\u3001\u4fee\u7406\u548c\u5176\u4ed6\u670d\u52a1\u4e1a",
#                 "\u4fe1\u606f\u4f20\u8f93\u3001\u8f6f\u4ef6\u548c\u4fe1\u606f\u6280\u672f\u670d\u52a1\u4e1a",
#                 "\u5efa\u7b51\u4e1a",
#                 "\u7535\u529b\u3001\u70ed\u529b\u3001\u71c3\u6c14\u53ca\u6c34\u751f\u4ea7\u548c\u4f9b\u5e94\u4e1a",
#                 "\u519c\u3001\u6797\u3001\u7267\u3001\u6e14\u4e1a",
#                 "\u91c7\u77ff\u4e1a"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u4ea7\u4e1a\u6574\u4f53\u6570\u91cf\u5206\u5e03\u5bf9\u6bd4\uff082010-2018\u5e74\uff09"
#         }
#     ]
# };
#         chart_56da0109f0a54dfab79bbe7fc6d4feb9.setOption(option_56da0109f0a54dfab79bbe7fc6d4feb9);
#     });
# </script>

# %% [markdown]
# ## 1.2专利总量及各产业时间变化趋势（2010-2018年）

# %%
total_year_df = pd.read_excel(path, sheet_name = "专利总数时间变化趋势（2010-2018年）")
total_year_df.loc["专利总量", :] = total_year_df.sum()
total_year_df.set_index("二级产业", inplace = True)

index = total_year_df.index.tolist()
index[7] = "专利总量"
total_year_df.index = index

##########################################################################################################
## 绘制专利总量逐年变化趋势
##########################################################################################################
def bar_horizon(total_year_df) -> Bar:
    
    df = total_year_df
    
    c = (
        Bar(init_opts=opts.InitOpts(width="960px", height="400px"))
        .add_xaxis(df.columns.tolist())
        .add_yaxis("专利总量", df.loc["专利总量", :].tolist(), category_gap="80%")
        .set_series_opts(label_opts=opts.LabelOpts(position="top"))
        .set_global_opts(
                         #title_opts=opts.TitleOpts(title="专利总数时间变化趋势（2010-2018年）"), 
                         legend_opts = opts.LegendOpts(pos_right = "1%", pos_bottom = "50%", orient = "vertical", is_show = False), 
                         xaxis_opts=opts.AxisOpts(is_show = True))
    )
    return c

c_totalyearBar = bar_horizon(total_year_df)
c_totalyearBar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="93213067474f4b81b743d6a337d769da" style="width:960px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_93213067474f4b81b743d6a337d769da = echarts.init(
#             document.getElementById('93213067474f4b81b743d6a337d769da'), 'white', {renderer: 'canvas'});
#         var option_93213067474f4b81b743d6a337d769da = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e13\u5229\u603b\u91cf",
#             "data": [
#                 688801.0,
#                 866076.0,
#                 1237778.0,
#                 1618483.0,
#                 1766723.0,
#                 2321407.0,
#                 2453868.0,
#                 2842018.0,
#                 3897036.0
#             ],
#             "barCategoryGap": "80%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e13\u5229\u603b\u91cf"
#             ],
#             "selected": {
#                 "\u4e13\u5229\u603b\u91cf": true
#             },
#             "show": false,
#             "right": "1%",
#             "bottom": "50%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2014,
#                 2015,
#                 2016,
#                 2017,
#                 2018
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ]
# };
#         chart_93213067474f4b81b743d6a337d769da.setOption(option_93213067474f4b81b743d6a337d769da);
#     });
# </script>

# %%
rate_year_df = pd.read_excel(path, sheet_name = "各产业逐年增长率时间变化趋势")
rate_year_df.set_index("二级产业", inplace = True)

##########################################################################################################
## 绘制各产业逐年增长率时间变化趋势
##########################################################################################################
def line_base(rate_year_df) -> Line:
    
    df = rate_year_df
    
    c = (
        Line(init_opts=opts.InitOpts(width="960px", height="400px"))
        .add_xaxis([str(x) for x in df.columns.tolist()])
        .add_yaxis("制造业", df.loc['制造业', :].tolist())
        .add_yaxis("居民服务、修理和其他服务业", df.loc['居民服务、修理和其他服务业', :].tolist())
        .add_yaxis("信息传输、软件和信息技术服务业", df.loc['信息传输、软件和信息技术服务业', :].tolist())
        .add_yaxis("建筑业", df.loc['建筑业', :].tolist())
        .add_yaxis("电力、热力、燃气及水生产和供应业", df.loc['电力、热力、燃气及水生产和供应业', :].tolist())
        .add_yaxis("农、林、牧、渔业", df.loc['农、林、牧、渔业', :].tolist())
        .add_yaxis("采矿业", df.loc['采矿业', :].tolist())
        .set_series_opts(label_opts=opts.LabelOpts(is_show = False), 
                         markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(x = "2016")]),
                                                               )
        .set_global_opts(title_opts=opts.TitleOpts(title=""), 
                         yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter="{value}%")), 
                         legend_opts = opts.LegendOpts(pos_right = "1%", pos_top = "1%", orient = "horizontal", is_show = True))
    )
    return c

c_rateLine = line_base(rate_year_df)
c_rateLine.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="edd6ae165b2d4c8794f7e19bd66c3cc8" style="width:960px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_edd6ae165b2d4c8794f7e19bd66c3cc8 = echarts.init(
#             document.getElementById('edd6ae165b2d4c8794f7e19bd66c3cc8'), 'white', {renderer: 'canvas'});
#         var option_edd6ae165b2d4c8794f7e19bd66c3cc8 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u5236\u9020\u4e1a",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010",
#                     NaN
#                 ],
#                 [
#                     "2011",
#                     25.0474454426729
#                 ],
#                 [
#                     "2012",
#                     44.28259734359
#                 ],
#                 [
#                     "2013",
#                     30.6207178581035
#                 ],
#                 [
#                     "2014",
#                     8.22679112704954
#                 ],
#                 [
#                     "2015",
#                     30.8787244542005
#                 ],
#                 [
#                     "2016",
#                     4.75268261807686
#                 ],
#                 [
#                     "2017",
#                     14.3910608473713
#                 ],
#                 [
#                     "2018",
#                     37.8448718460881
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "xAxis": "2016"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5c45\u6c11\u670d\u52a1\u3001\u4fee\u7406\u548c\u5176\u4ed6\u670d\u52a1\u4e1a",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010",
#                     NaN
#                 ],
#                 [
#                     "2011",
#                     25.3741574317377
#                 ],
#                 [
#                     "2012",
#                     47.0430107526882
#                 ],
#                 [
#                     "2013",
#                     35.2058996684535
#                 ],
#                 [
#                     "2014",
#                     14.3164890569497
#                 ],
#                 [
#                     "2015",
#                     27.4126939577403
#                 ],
#                 [
#                     "2016",
#                     13.4212348165397
#                 ],
#                 [
#                     "2017",
#                     12.3213938906306
#                 ],
#                 [
#                     "2018",
#                     57.8920067187037
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "xAxis": "2016"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u4fe1\u606f\u4f20\u8f93\u3001\u8f6f\u4ef6\u548c\u4fe1\u606f\u6280\u672f\u670d\u52a1\u4e1a",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010",
#                     NaN
#                 ],
#                 [
#                     "2011",
#                     26.2690355329949
#                 ],
#                 [
#                     "2012",
#                     56.8557071069634
#                 ],
#                 [
#                     "2013",
#                     34.0137299771167
#                 ],
#                 [
#                     "2014",
#                     19.8688614165699
#                 ],
#                 [
#                     "2015",
#                     50.1937321937322
#                 ],
#                 [
#                     "2016",
#                     9.73481543305892
#                 ],
#                 [
#                     "2017",
#                     23.5955056179775
#                 ],
#                 [
#                     "2018",
#                     -2.79160839160839
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markLine": {
#                 "silent": false,
#                 "precision": 2,
#                 "label": {
#                     "show": true,
#                     "position": "top",
#                     "margin": 8
#                 },
#                 "data": [
#                     {
#                         "xAxis": "2016"
#                     }
#                 ]
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5efa\u7b51\u4e1a",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010",
#                     NaN
#                 ],
#                 [
#                     "2011",
#                     23.5614192009541
#                 ],
#                 [
#                     "2012",
#                     26.8504554503227

# %%
compete_df = pd.read_excel(path, sheet_name = "2017年各行业竞争对比气泡图")
compete_df.set_index("二级产业", inplace = True)

##########################################################################################################
## 绘制2017年各行业竞争对比气泡图
##########################################################################################################
def scatter_visualmap_color(compete_df) -> Scatter:
    
    df = compete_df
    
    c = (
        Scatter(init_opts=opts.InitOpts(width="960px", height="400px"))
        .add_xaxis([str(x) for x in df["专利数"].tolist()])
        #.add_yaxis("", df["平均增长率"].round(2).tolist())
        .add_yaxis("制造业", df["制造业"].tolist())
        .add_yaxis("居民服务、修理和其他服务业", df["居民服务、修理和其他服务业"].tolist())
        .add_yaxis("信息传输、软件和信息技术服务业", df["信息传输、软件和信息技术服务业"].tolist())
        .add_yaxis("建筑业", df["建筑业"].tolist())
        .add_yaxis("电力、热力、燃气及水生产和供应业", df["电力、热力、燃气及水生产和供应业"].tolist())
        .add_yaxis("农、林、牧、渔业", df["农、林、牧、渔业"].tolist())
        .add_yaxis("采矿业", df["采矿业"].tolist())
        .set_global_opts(
            #title_opts=opts.TitleOpts(title="2017年各行业竞争对比"),
            xaxis_opts=opts.AxisOpts(type_ = "value"),
            yaxis_opts=opts.AxisOpts(is_scale = True),
            visualmap_opts=opts.VisualMapOpts(type_="size", min_ = 18, max_ = 30),
            legend_opts = opts.LegendOpts(is_show = False),
        )
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{a}", position="right"))
    )
    return c

c_bubble = scatter_visualmap_color(compete_df)
c_bubble.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="9ebfc1821bb8474fbcd13649ffb6b47d" style="width:960px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_9ebfc1821bb8474fbcd13649ffb6b47d = echarts.init(
#             document.getElementById('9ebfc1821bb8474fbcd13649ffb6b47d'), 'white', {renderer: 'canvas'});
#         var option_9ebfc1821bb8474fbcd13649ffb6b47d = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u5236\u9020\u4e1a",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "26806",
#                     NaN
#                 ],
#                 [
#                     "74216",
#                     NaN
#                 ],
#                 [
#                     "106585",
#                     NaN
#                 ],
#                 [
#                     "551083",
#                     NaN
#                 ],
#                 [
#                     "34210",
#                     NaN
#                 ],
#                 [
#                     "117147",
#                     NaN
#                 ],
#                 [
#                     "2333174",
#                     24.5056114421441
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5c45\u6c11\u670d\u52a1\u3001\u4fee\u7406\u548c\u5176\u4ed6\u670d\u52a1\u4e1a",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "26806",
#                     NaN
#                 ],
#                 [
#                     "74216",
#                     NaN
#                 ],
#                 [
#                     "106585",
#                     NaN
#                 ],
#                 [
#                     "551083",
#                     29.1233607866804
#                 ],
#                 [
#                     "34210",
#                     NaN
#                 ],
#                 [
#                     "117147",
#                     NaN
#                 ],
#                 [
#                     "2333174",
#                     NaN
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u4fe1\u606f\u4f20\u8f93\u3001\u8f6f\u4ef6\u548c\u4fe1\u606f\u6280\u672f\u670d\u52a1\u4e1a",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "26806",
#                     NaN
#                 ],
#                 [
#                     "74216",
#                     NaN
#                 ],
#                 [
#                     "106585",
#                     NaN
#                 ],
#                 [
#                     "551083",
#                     NaN
#                 ],
#                 [
#                     "34210",
#                     NaN
#                 ],
#                 [
#                     "117147",
#                     27.2174723608506
#                 ],
#                 [
#                     "2333174",
#                     NaN
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5efa\u7b51\u4e1a",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "26806",
#                     NaN
#                 ],
#                 [
#                     "74216",
#                     NaN
#                 ],
#                 [
#                     "106585",
#                     23.8877692830697
#                 ],
#                 [
#                     "551083",
#                     NaN
#                 ],
#                 [
#                     "34210",
#                     NaN
#                 ],
#                 [
#                     "117147",
#                     NaN
#                 ],
#                 [
#                     "2333174",
#                     NaN
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u7535\u529b\u3001\u70ed\u529b\u3001\u71c3\u6c14\u53ca\u6c34\u751f\u4ea7\u548c\u4f9b\u5e94\u4e1a",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "26806",
#                     NaN
#                 ],
#                 [
#                     "74216",
#                     26.499892093363
#                 ],
#                 [
#                     "106585",
#                     NaN
#                 ],
#                 [
#                     "551083",
#                     NaN
#                 ],
#                 [
#                     "34210",
#                     NaN
#                 ],
#                 [
#                     "117147",
#                     NaN
#                 ],
#                 [
#                     "2333174",
#                     NaN
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u519c\u3001\u6797\u3001\u7267\u3001\u6e14\u4e1a",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "26806",
#                     NaN
#                 ],
#                 [
#                     "74216",
#                     NaN
#                 ],
#                 [
#                     "106585",
#                     NaN
#                 ],
#                 [
#                     "551083",
#                     NaN
#                 ],
#                 [
#                     "34210",
#                     21.7056217367634
#                 ],
#                 [
#                     "117147",
#                     NaN
#                 ],
#                 [
#                     "2333174",
#                     NaN
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {

# %% [markdown]
# ## 1.3各产业区域分部特点（2010-2018年)

# %%
pro_df  = pd.read_excel(path, sheet_name = "省级行政区区域各产业专利规模")

pro_df = pro_df.reset_index()

col_name = pro_df.columns.tolist()
col_name[0] = "省份"
col_name[8] = "总专利数"
pro_df.columns = col_name

##########################################################################################################
## 绘制专利数省份柱状分布地图
##########################################################################################################

def bar_stack(pro_df) -> Bar:
    
    df = pro_df.sort_values(by = "总专利数", ascending = False)
    
    c = (
        Bar()
        .add_xaxis(df["省份"].tolist())
        .add_yaxis("总专利数", df["总专利数"].tolist())
        .add_yaxis("制造业", df["制造业"].tolist())
        .add_yaxis("居民服务、修理和其他服务业", df["居民服务、修理和其他服务业"].tolist())
        .add_yaxis("信息传输、软件和信息技术服务业", df["信息传输、软件和信息技术服务业"].tolist())
        .add_yaxis("建筑业", df["建筑业"].tolist(), is_selected=False)
        .add_yaxis("电力、热力、燃气及水生产和供应业", df["电力、热力、燃气及水生产和供应业"].tolist(), is_selected=False)
        .add_yaxis("农、林、牧、渔业", df["农、林、牧、渔业"].tolist(), is_selected=False)
        .add_yaxis("采矿业", df["采矿业"].tolist(), is_selected=False)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="省级行政区区域各产业专利规模"), 
                         legend_opts = opts.LegendOpts(pos_right = "1%", pos_top = "15%", orient = "vertical"), 
                         datazoom_opts = opts.DataZoomOpts(type_ = "slider", range_start = 0, range_end = 50))
    )
    return c

c_bar_pro = bar_stack(pro_df)
c_bar_pro.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="7f72e7c52cdf4cb8880383a2545eff1f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_7f72e7c52cdf4cb8880383a2545eff1f = echarts.init(
#             document.getElementById('7f72e7c52cdf4cb8880383a2545eff1f'), 'white', {renderer: 'canvas'});
#         var option_7f72e7c52cdf4cb8880383a2545eff1f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u4e13\u5229\u6570",
#             "data": [
#                 2668783,
#                 2537192,
#                 1824861,
#                 1446842,
#                 1233338,
#                 936763,
#                 883678,
#                 664891,
#                 534642,
#                 523798,
#                 519918,
#                 491225,
#                 394802,
#                 377094,
#                 370325,
#                 359335,
#                 289610,
#                 259743,
#                 221756,
#                 204336,
#                 137433,
#                 129232,
#                 127186,
#                 112708,
#                 86360,
#                 71353,
#                 58284,
#                 35133,
#                 31961,
#                 22428,
#                 14893,
#                 4315,
#                 3052,
#                 272
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5236\u9020\u4e1a",
#             "data": [
#                 1778442,
#                 1930380,
#                 1379112,
#                 896710,
#                 943494,
#                 718328,
#                 624755,
#                 475552,
#                 398934,
#                 380907,
#                 385488,
#                 356787,
#                 294659,
#                 279997,
#                 266010,
#                 267805,
#                 216872,
#                 201278,
#                 166476,
#                 155557,
#                 103367,
#                 96303,
#                 96152,
#                 87790,
#                 66749,
#                 53160,
#                 44367,
#                 26543,
#                 22402,
#                 16724,
#                 10956,
#                 3806,
#                 2216,
#                 186
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5c45\u6c11\u670d\u52a1\u3001\u4fee\u7406\u548c\u5176\u4ed6\u670d\u52a1\u4e1a",
#             "data": [
#                 617016.0,
#                 383900.0,
#                 296778.0,
#                 298198.0,
#                 165763.0,
#                 137034.0,
#                 155613.0,
#                 105534.0,
#                 77541.0,
#                 82156.0,
#                 84683.0,
#                 81925.0,
#                 65724.0,
#                 55203.0,
#                 56078.0,
#                 51593.0,
#                 37060.0,
#                 28542.0,
#                 29397.0,
#                 31236.0,
#                 15511.0,
#                 13459.0,
#                 14018.0,
#                 13902.0,
#                 8265.0,
#                 6707.0,
#                 6452.0,
#                 4764.0,
#                 7351.0,
#                 2716.0,
#                 1498.0,
#                 NaN,
#                 410.0,
#                 55.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u4fe1\u606f\u4f20\u8f93\u3001\u8f6f\u4ef6\u548c\u4fe1\u606f\u6280\u672f\u670d\u52a1\u4e1a",
#             "data": [
#                 166628,
#                 57046,
#                 37821,
#                 139568,
#                 26901,
#                 15869,
#                 46437,
#                 27625,
#                 12247,
#                 17314,
#                 13768,
#                 13638,
#                 8693,
#                 10580,
#                 16971,
#                 10124,
#                 5596,
#                 5326,
#                 6333,
#                 3841,
#                 2717,
#                 2830,
#                 2112,
#                 2834,
#                 1282,
#                 1042,
#                 1075,
#                 745,
#                 1380,
#                 717,
#                 272,
#                 257,
#                 86,
#                 13
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5efa\u7b51\u4e1a",
#             "data": [
#                 38357,
#                 71967,
#                 55649,
#                 39610,
#                 40662,
#                 24581,
#                 27111,
#                 23399,
#                 21585,
#                 21206,
#                 15409,
#                 17167,
#                 10795,
#                 12653,
#                 12659,
#                 12318,
#                 14924,
#                 5314,
#                 5896,
#                 5401,
#                 5659,
#                 4819,
#                 7662,
#                 2572,
#                 3223,
#                 2755,
#                 2419,
#                 1161,
#                 235,
#                 616,
#                 915,
#                 106,
#                 124,
#                 5
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u7535\u529b\u3001\u70ed\u529b\u3001\u71c3\u6c14\u53ca\u6c34\u751f\u4ea7\u548c\u4f9b\u5e94\u4e1a",
#             "data": [
#                 49405,
#                 56891,
#                 34656,
#                 37304,
#                 24975,
#                 16654,
#                 20077,
#                 15832,
#                 11291,
#                 10881,
#                 11198,
#                 12670,
#                 6927,
#                 9330,
#                 8350,
#                 8632,

# %%
##########################################################################################################
## 绘制专利数省份热力分布地图
##########################################################################################################

def map_visualmap(pro_df) -> Map:
    
    df = pro_df
    
    c = (
        Map()
        .add("总专利数", [list(z) for z in zip(df["省份"].tolist(), df["总专利数"].tolist())], "china")
        .add("制造业", [list(z) for z in zip(df["省份"].tolist(), df["制造业"].tolist())], "china", is_selected=False)
        .add("居民服务、修理和其他服务业", [list(z) for z in zip(df["省份"].tolist(), df["居民服务、修理和其他服务业"].tolist())], "china", is_selected=False)
        .add("信息传输、软件和信息技术服务业", [list(z) for z in zip(df["省份"].tolist(), df["信息传输、软件和信息技术服务业"].tolist())], "china", is_selected=False)
        .add("电力、热力、燃气及水生产和供应业", [list(z) for z in zip(df["省份"].tolist(), df["电力、热力、燃气及水生产和供应业"].tolist())], "china", is_selected=False)
        .add("农、林、牧、渔业", [list(z) for z in zip(df["省份"].tolist(), df["农、林、牧、渔业"].tolist())], "china", is_selected=False)
        .add("采矿业", [list(z) for z in zip(df["省份"].tolist(), df["采矿业"].tolist())], "china", is_selected=False)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="省级行政区区域各产业专利规模"),
            visualmap_opts=opts.VisualMapOpts(max_=df["总专利数"].max().tolist(), is_piecewise=False, orient = "horizontal", pos_bottom = "10%", pos_left = "5%"),
            legend_opts = opts.LegendOpts(pos_right = "1%", pos_bottom = "1%", type_ = "scroll"),
        )
    )
    return c

c_map_GIS = map_visualmap(pro_df)
c_map_GIS.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="5d4c1e0e5fc24419a2cf35b6c293adf0" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_5d4c1e0e5fc24419a2cf35b6c293adf0 = echarts.init(
#             document.getElementById('5d4c1e0e5fc24419a2cf35b6c293adf0'), 'white', {renderer: 'canvas'});
#         var option_5d4c1e0e5fc24419a2cf35b6c293adf0 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u603b\u4e13\u5229\u6570",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 936763
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 272
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 1446842
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 519918
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 86360
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 2668783
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 259743
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 137433
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 22428
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 289610
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 534642
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 221756
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 523798
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 359335
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 112708
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 2537192
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 204336
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 377094
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 58284
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 35133
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 14893
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 1233338
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 127186
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 370325
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 883678
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 664891
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 31961
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 491225
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 3052
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 4315
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 71353
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 129232
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 1824861
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 394802
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "map",
#             "name": "\u5236\u9020\u4e1a",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 718328
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 186
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 896710
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 385488
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 66749
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 1778442
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 201278
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 103367
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 16724
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 216872
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 398934
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 166476
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 380907
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 267805
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 87790
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 1930380
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 155557
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 279997
#                 },

# %% [markdown]
# ## 3.1 广东、浙江、江苏专利转移规模最大

# %%
##########################################################################################################
## 数据清洗，筛选出正确地区并合并重复项，清除不明确地区项
##########################################################################################################
trans_df = pd.read_excel(path, sheet_name = "trans")
def toDistrict(pro):
    if pro in ["黑龙江", "吉林", "辽宁", "内蒙古"]: 
        pro = "东北"
    if pro in ["北京", "天津", "山西", "河北"]:
        pro = "华北"
    if pro in ["上海", "江苏", "浙江", "安徽", "福建", "江西", "山东", "台湾"]:
        pro = "华东"
    if pro in ["河南", "湖北", "湖南", "广西", "广东", "香港", "澳门", "海南"]:
        pro = "华南"
    if pro in ["重庆", "四川", "贵州", "云南", "西藏"]:
        pro = "西南"
    if pro in ["陕西", "甘肃", "青海", "宁夏", "新疆"]:
        pro = "西北"
    
    return pro
trans_district_df = trans_df
trans_district_df[["转入", "转出"]] = trans_df[["转入", "转出"]].applymap(toDistrict)
##########################################################################################################
## 数据清洗，筛选出正确地区并合并重复项，清除不明确地区项
##########################################################################################################
trans_district_df = trans_district_df.groupby(['转出', '转入']).sum().reset_index()

def cleanFilter(item):
    district = ["东北", "华北", "华东", "华南", "西南", "西北"]
    if item in district:
        index = True
    else:
        index = False
    return index

trans_district_df = trans_district_df[(trans_district_df["转出"].map(cleanFilter)) & (trans_district_df["转入"].map(cleanFilter))]

##########################################################################################################
## 生成Sankey可用的数据框格式
##########################################################################################################
trans_district_melt = trans_district_df.melt(id_vars = ["转出", "转入"], var_name = "Year", value_name = "Amount")
trans_district_melt["转出-年"] = trans_district_melt["转出"] + (["-"] * len(trans_district_melt)) + [str(i) for i in trans_district_melt["Year"]]
trans_district_melt["转入-年"] = trans_district_melt["转入"] + (["-"] * len(trans_district_melt)) + [str(i+1) for i in trans_district_melt["Year"]]

trans_district_pivot = trans_district_melt.pivot_table(index = ["转出-年"], columns = ["转入-年"], values = ["Amount"])
trans_district_pivot.columns = trans_district_pivot.columns.levels[1].tolist()

##########################################################################################################
## 绘制Sankey图——区域流向图
##########################################################################################################
nodes = []
for item in trans_district_pivot.index:
    nodes.append({"name": item})
for item in trans_district_pivot.columns:
    if item not in trans_district_pivot.index.tolist():
        nodes.append({"name": item})

links = []
for col in trans_district_pivot:
    for index in trans_district_pivot[col].index:
        if not math.isnan(trans_district_pivot[col][index]):
            links.append({"source": index, "target": col, "value": trans_district_pivot[col][index].tolist()})

def sankey_base(node, link) -> Sankey:
    
    nodes = node
    links = link
    
    c = (
        Sankey()
        .add(
            "sankey",
            nodes,
            links,
            linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
            label_opts=opts.LabelOpts(position="right"),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="Sankey-基本示例"))
    )

    return c

c = sankey_base(nodes, links)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="201e16947e7c4162aef2ec670d62b790" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_201e16947e7c4162aef2ec670d62b790 = echarts.init(
#             document.getElementById('201e16947e7c4162aef2ec670d62b790'), 'white', {renderer: 'canvas'});
#         var option_201e16947e7c4162aef2ec670d62b790 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "\u4e1c\u5317-2010"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2011"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2012"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2013"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2014"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2015"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2016"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2017"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2018"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2010"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2011"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2012"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2013"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2014"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2015"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2016"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2017"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2018"
#                 },
#                 {
#                     "name": "\u534e\u5317-2010"
#                 },
#                 {
#                     "name": "\u534e\u5317-2011"
#                 },
#                 {
#                     "name": "\u534e\u5317-2012"
#                 },
#                 {
#                     "name": "\u534e\u5317-2013"
#                 },
#                 {
#                     "name": "\u534e\u5317-2014"
#                 },
#                 {
#                     "name": "\u534e\u5317-2015"
#                 },
#                 {
#                     "name": "\u534e\u5317-2016"
#                 },
#                 {
#                     "name": "\u534e\u5317-2017"
#                 },
#                 {
#                     "name": "\u534e\u5317-2018"
#                 },
#                 {
#                     "name": "\u534e\u5357-2010"
#                 },
#                 {
#                     "name": "\u534e\u5357-2011"
#                 },
#                 {
#                     "name": "\u534e\u5357-2012"
#                 },
#                 {
#                     "name": "\u534e\u5357-2013"
#                 },
#                 {
#                     "name": "\u534e\u5357-2014"
#                 },
#                 {
#                     "name": "\u534e\u5357-2015"
#                 },
#                 {
#                     "name": "\u534e\u5357-2016"
#                 },
#                 {
#                     "name": "\u534e\u5357-2017"
#                 },
#                 {
#                     "name": "\u534e\u5357-2018"
#                 },
#                 {
#                     "name": "\u897f\u5317-2010"
#                 },
#                 {
#                     "name": "\u897f\u5317-2011"
#                 },
#                 {
#                     "name": "\u897f\u5317-2012"
#                 },
#                 {
#                     "name": "\u897f\u5317-2013"
#                 },
#                 {
#                     "name": "\u897f\u5317-2014"
#                 },
#                 {
#                     "name": "\u897f\u5317-2015"
#                 },
#                 {
#                     "name": "\u897f\u5317-2016"
#                 },
#                 {
#                     "name": "\u897f\u5317-2017"
#                 },
#                 {
#                     "name": "\u897f\u5317-2018"
#                 },
#                 {
#                     "name": "\u897f\u5357-2010"
#                 },
#                 {
#                     "name": "\u897f\u5357-2011"
#                 },
#                 {
#                     "name": "\u897f\u5357-2012"
#                 },
#                 {
#                     "name": "\u897f\u5357-2013"
#                 },
#                 {
#                     "name": "\u897f\u5357-2014"
#                 },
#                 {
#                     "name": "\u897f\u5357-2015"
#                 },
#                 {
#                     "name": "\u897f\u5357-2016"
#                 },
#                 {
#                     "name": "\u897f\u5357-2017"
#                 },
#                 {
#                     "name": "\u897f\u5357-2018"
#                 },
#                 {
#                     "name": "\u4e1c\u5317-2019"
#                 },
#                 {
#                     "name": "\u534e\u4e1c-2019"
#                 },
#                 {
#                     "name": "\u534e\u5317-2019"
#                 },
#                 {
#                     "name": "\u534e\u5357-2019"
#                 },
#                 {
#                     "name": "\u897f\u5317-2019"
#                 },
#                 {
#                     "name": "\u897f\u5357-2019"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "\u4e1c\u5317-2010",
#                     "target": "\u4e1c\u5317-2011",
#                     "value": 1117.0
#                 },
#                 {
#                     "source": "\u534e\u4e1c-2010",
#                     "target": "\u4e1c\u5317-2011",
#                     "value": 102.0
#                 },
#                 {
#                     "source": "\u534e\u5317-2010",
#                     "target": "\u4e1c\u5317-2011",
#                     "value": 82.0
#                 },
#                 {
#                     "source": "\u534e\u5357-2010",
#                     "target": "\u4e1c\u5317-2011",
#                     "value": 20.0
#                 },
#                 {
#                     "source": "\u897f\u5317-2010",
#                     "target": "\u4e1c\u5317-2011",
#                     "value": 4.0
#                 },
#                 {
#                     "source": "\u897f\u5357-2010",
#                     "target": "\u4e1c\u5317-2011",
#                     "value": 1.0
#                 },
#                 {
#                     "source": "\u4e1c\u5317-2011",
#                     "target": "\u4e1c\u5317-2012",
#                     "value": 2177.0
#                 },
#                 {
#                     "source": "\u534e\u4e1c-2011",
#                     "target": "\u4e1c\u5317-2012",
#                     "value": 87.0
#                 },
#                 {
#                     "source": "\u534e\u5317-2011",
#                     "target": "\u4e1c\u5317-2012",
#                     "value": 112.0
#                 },
#                 {
#                     "source": "\u534e\u5357-2011",
#                     "target": "\u4e1c\u5317-2012",
#                     "value": 84.0
#                 },
#                 {

# %%
##########################################################################################################
## 数据清洗，筛选出正确地区并合并重复项，清除不明确地区项
##########################################################################################################
trans_df = pd.read_excel(path, sheet_name = "trans")
def toDistrict(pro):
    if pro in ["黑龙江", "吉林", "辽宁", "内蒙古"]: 
        pro = "东北"
    if pro in ["北京", "天津", "山西", "河北"]:
        pro = "华北"
    if pro in ["上海", "江苏", "浙江", "安徽", "福建", "江西", "山东", "台湾"]:
        pro = "华东"
    if pro in ["河南", "湖北", "湖南", "广西", "广东", "香港", "澳门", "海南"]:
        pro = "华南"
    if pro in ["重庆", "四川", "贵州", "云南", "西藏"]:
        pro = "西南"
    if pro in ["陕西", "甘肃", "青海", "宁夏", "新疆"]:
        pro = "西北"
    
    return pro
trans_district_df = trans_df
trans_district_df[["转入", "转出"]] = trans_df[["转入", "转出"]].applymap(toDistrict)
trans_district_df = trans_district_df.loc[:,["转出", "转入", 2018]]

##########################################################################################################
## 数据清洗，筛选出正确地区并合并重复项，清除不明确地区项
##########################################################################################################
trans_district_df = trans_district_df.groupby(['转出', '转入']).sum().reset_index()

def cleanFilter(item):
    district = ["东北", "华北", "华东", "华南", "西南", "西北"]
    if item in district:
        index = True
    else:
        index = False
    return index

trans_district_df = trans_district_df[(trans_district_df["转出"].map(cleanFilter)) & (trans_district_df["转入"].map(cleanFilter))]

##########################################################################################################
## 生成Sankey可用的数据框格式
##########################################################################################################
def trans_out(district):
    district = district + "_转出"
    
    return district

def trans_in(district):
    district = district + "_转入"
    
    return district

trans_district_df["转出"] = trans_district_df["转出"].map(trans_out)
trans_district_df["转入"] = trans_district_df["转入"].map(trans_in)

trans_district_pivot = trans_district_df.pivot_table(index = ["转出"], columns = ["转入"], values = [2018])
trans_district_pivot.columns = trans_district_pivot.columns.levels[1].tolist()

##########################################################################################################
## 绘制Sankey图——区域流向图
##########################################################################################################
nodes = []
for item in trans_district_pivot.index:
    nodes.append({"name": item})
for item in trans_district_pivot.columns:
    if item not in trans_district_pivot.index.tolist():
        nodes.append({"name": item})

links = []
for col in trans_district_pivot:
    for index in trans_district_pivot[col].index:
        if not math.isnan(trans_district_pivot[col][index]):
            links.append({"source": index, "target": col, "value": trans_district_pivot[col][index].tolist()})

def sankey_base(node, link) -> Sankey:
    
    nodes = node
    links = link
    
    c = (
        Sankey()
        .add(
            "sankey",
            nodes,
            links,
            linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
            label_opts=opts.LabelOpts(position="right"),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="2018年专利各区域间转移情况"), 
                         legend_opts = opts.LegendOpts(is_show = False))
    )

    return c

c = sankey_base(nodes, links)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="32f343a5e6db4cf694a50666d9406800" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_32f343a5e6db4cf694a50666d9406800 = echarts.init(
#             document.getElementById('32f343a5e6db4cf694a50666d9406800'), 'white', {renderer: 'canvas'});
#         var option_32f343a5e6db4cf694a50666d9406800 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "name": "sankey",
#             "data": [
#                 {
#                     "name": "\u4e1c\u5317_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u534e\u4e1c_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u534e\u5317_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u534e\u5357_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u897f\u5317_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u897f\u5357_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u4e1c\u5317_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u534e\u4e1c_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u534e\u5317_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u534e\u5357_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u897f\u5317_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u897f\u5357_\u8f6c\u5165"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "\u4e1c\u5317_\u8f6c\u51fa",
#                     "target": "\u4e1c\u5317_\u8f6c\u5165",
#                     "value": 4089
#                 },
#                 {
#                     "source": "\u534e\u4e1c_\u8f6c\u51fa",
#                     "target": "\u4e1c\u5317_\u8f6c\u5165",
#                     "value": 935
#                 },
#                 {
#                     "source": "\u534e\u5317_\u8f6c\u51fa",
#                     "target": "\u4e1c\u5317_\u8f6c\u5165",
#                     "value": 669
#                 },
#                 {
#                     "source": "\u534e\u5357_\u8f6c\u51fa",
#                     "target": "\u4e1c\u5317_\u8f6c\u5165",
#                     "value": 535
#                 },
#                 {
#                     "source": "\u897f\u5317_\u8f6c\u51fa",
#                     "target": "\u4e1c\u5317_\u8f6c\u5165",
#                     "value": 69
#                 },
#                 {
#                     "source": "\u897f\u5357_\u8f6c\u51fa",
#                     "target": "\u4e1c\u5317_\u8f6c\u5165",
#                     "value": 111
#                 },
#                 {
#                     "source": "\u4e1c\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u4e1c_\u8f6c\u5165",
#                     "value": 977
#                 },
#                 {
#                     "source": "\u534e\u4e1c_\u8f6c\u51fa",
#                     "target": "\u534e\u4e1c_\u8f6c\u5165",
#                     "value": 65929
#                 },
#                 {
#                     "source": "\u534e\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u4e1c_\u8f6c\u5165",
#                     "value": 4195
#                 },
#                 {
#                     "source": "\u534e\u5357_\u8f6c\u51fa",
#                     "target": "\u534e\u4e1c_\u8f6c\u5165",
#                     "value": 9058
#                 },
#                 {
#                     "source": "\u897f\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u4e1c_\u8f6c\u5165",
#                     "value": 607
#                 },
#                 {
#                     "source": "\u897f\u5357_\u8f6c\u51fa",
#                     "target": "\u534e\u4e1c_\u8f6c\u5165",
#                     "value": 1611
#                 },
#                 {
#                     "source": "\u4e1c\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u5317_\u8f6c\u5165",
#                     "value": 393
#                 },
#                 {
#                     "source": "\u534e\u4e1c_\u8f6c\u51fa",
#                     "target": "\u534e\u5317_\u8f6c\u5165",
#                     "value": 4156
#                 },
#                 {
#                     "source": "\u534e\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u5317_\u8f6c\u5165",
#                     "value": 14849
#                 },
#                 {
#                     "source": "\u534e\u5357_\u8f6c\u51fa",
#                     "target": "\u534e\u5317_\u8f6c\u5165",
#                     "value": 1760
#                 },
#                 {
#                     "source": "\u897f\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u5317_\u8f6c\u5165",
#                     "value": 228
#                 },
#                 {
#                     "source": "\u897f\u5357_\u8f6c\u51fa",
#                     "target": "\u534e\u5317_\u8f6c\u5165",
#                     "value": 715
#                 },
#                 {
#                     "source": "\u4e1c\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u5357_\u8f6c\u5165",
#                     "value": 460
#                 },
#                 {
#                     "source": "\u534e\u4e1c_\u8f6c\u51fa",
#                     "target": "\u534e\u5357_\u8f6c\u5165",
#                     "value": 11383
#                 },
#                 {
#                     "source": "\u534e\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u5357_\u8f6c\u5165",
#                     "value": 2707
#                 },
#                 {
#                     "source": "\u534e\u5357_\u8f6c\u51fa",
#                     "target": "\u534e\u5357_\u8f6c\u5165",
#                     "value": 33399
#                 },
#                 {
#                     "source": "\u897f\u5317_\u8f6c\u51fa",
#                     "target": "\u534e\u5357_\u8f6c\u5165",
#                     "value": 291
#                 },
#                 {
#                     "source": "\u897f\u5357_\u8f6c\u51fa",
#                     "target": "\u534e\u5357_\u8f6c\u5165",
#                     "value": 1410
#                 },
#                 {
#                     "source": "\u4e1c\u5317_\u8f6c\u51fa",
#                     "target": "\u897f\u5317_\u8f6c\u5165",
#                     "value": 47
#                 },
#                 {
#                     "source": "\u534e\u4e1c_\u8f6c\u51fa",
#                     "target": "\u897f\u5317_\u8f6c\u5165",
#                     "value": 1074
#                 },
#                 {
#                     "source": "\u534e\u5317_\u8f6c\u51fa",
#                     "target": "\u897f\u5317_\u8f6c\u5165",
#                     "value": 2202
#                 },
#                 {
#                     "source": "\u534e\u5357_\u8f6c\u51fa",
#                     "target": "\u897f\u5317_\u8f6c\u5165",
#                     "value": 438
#                 },
#                 {
#                     "source": "\u897f\u5317_\u8f6c\u51fa",
#                     "target": "\u897f\u5317_\u8f6c\u5165",
#                     "value": 2746
#                 },
#                 {
#                     "source": "\u897f\u5357_\u8f6c\u51fa",
#                     "target": "\u897f\u5317_\u8f6c\u5165",
#                     "value": 107
#                 },
#                 {
#                     "source": "\u4e1c\u5317_\u8f6c\u51fa",

# %%
##########################################################################################################
## 读取数据、添加列名、将省份转换成区域
##########################################################################################################
trans_df = pd.read_excel(path, sheet_name = "trans")
trans_df = trans_df.loc[:,["转出", "转入", 2018]]
##########################################################################################################
## 数据清洗，筛选出正确地区并合并重复项，清除不明确地区项
##########################################################################################################
trans_df = trans_df.groupby(['转出', '转入']).sum().reset_index()

def cleanFilter(item):
    province = ["北京", "天津", "河北", "山西", "内蒙古", "辽宁", 
                "吉林", "黑龙江", "上海", "江苏", "浙江", "安徽", 
                "福建", "江西", "山东", "河南", "湖北", "湖南", 
                "广东", "广西", "海南", "重庆", "四川", "贵州", 
                "云南", "西藏", "陕西", "甘肃", "青海", "宁夏", 
                "新疆", "台湾", "香港", "澳门"]
    
    if item in province:
        index = True
    else:
        index = False
    return index

trans_df = trans_df[(trans_df["转出"].map(cleanFilter)) & (trans_df["转入"].map(cleanFilter))]

##########################################################################################################
## 生成Sankey可用的数据框格式
##########################################################################################################
def trans_out(province):
    province = province + "_转出"
    
    return province

def trans_in(province):
    province = province + "_转入"
    
    return province

trans_df["转出"] = trans_df["转出"].map(trans_out)
trans_df["转入"] = trans_df["转入"].map(trans_in)

trans_pivot = trans_df.pivot_table(index = ["转出"], columns = ["转入"], values = [2018])
trans_pivot.columns = trans_pivot.columns.levels[1].tolist()

##########################################################################################################
## 绘制Sankey图——区域流向图
##########################################################################################################
nodes = []
for item in trans_pivot.index:
    nodes.append({"name": item})
for item in trans_pivot.columns:
    if item not in trans_district_pivot.index.tolist():
        nodes.append({"name": item})

links = []
for col in trans_pivot:
    for index in trans_pivot[col].index:
        if not math.isnan(trans_pivot[col][index]):
            links.append({"source": index, "target": col, "value": trans_pivot[col][index].tolist()})

def sankey_base(node, link) -> Sankey:
    
    nodes = node
    links = link
    
    c = (
        Sankey()
        .add(
            "",
            nodes,
            links,
            linestyle_opt=opts.LineStyleOpts(opacity=0.2, curve=0.5, color="source"),
            label_opts=opts.LabelOpts(position="right"),
        )
        .set_global_opts(title_opts=opts.TitleOpts(title="2018年专利各省份间转移情况"))
    )

    return c

c = sankey_base(nodes, links)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="47530118b5b944d4abd4700a9ecc63ee" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_47530118b5b944d4abd4700a9ecc63ee = echarts.init(
#             document.getElementById('47530118b5b944d4abd4700a9ecc63ee'), 'white', {renderer: 'canvas'});
#         var option_47530118b5b944d4abd4700a9ecc63ee = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "sankey",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u4e91\u5357_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5317\u4eac_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5409\u6797_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u56db\u5ddd_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5929\u6d25_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5b81\u590f_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5b89\u5fbd_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5c71\u4e1c_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5c71\u897f_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u5e7f\u897f_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u65b0\u7586_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u6c5f\u82cf_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u6c5f\u897f_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u6cb3\u5317_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u6cb3\u5357_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u6d59\u6c5f_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u6d77\u5357_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u6e56\u5317_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u6e56\u5357_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u7518\u8083_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u798f\u5efa_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u897f\u85cf_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u8d35\u5dde_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u8fbd\u5b81_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u91cd\u5e86_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u9655\u897f_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u9752\u6d77_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f_\u8f6c\u51fa"
#                 },
#                 {
#                     "name": "\u4e0a\u6d77_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u4e91\u5357_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5317\u4eac_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5409\u6797_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u56db\u5ddd_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5929\u6d25_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5b81\u590f_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5b89\u5fbd_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5c71\u4e1c_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5c71\u897f_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u5e7f\u897f_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u65b0\u7586_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u6c5f\u82cf_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u6c5f\u897f_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u6cb3\u5317_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u6cb3\u5357_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u6d59\u6c5f_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u6d77\u5357_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u6e56\u5317_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u6e56\u5357_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u7518\u8083_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u798f\u5efa_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u897f\u85cf_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u8d35\u5dde_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u8fbd\u5b81_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u91cd\u5e86_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u9655\u897f_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u9752\u6d77_\u8f6c\u5165"
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f_\u8f6c\u5165"
#                 }
#             ],
#             "links": [
#                 {
#                     "source": "\u4e0a\u6d77_\u8f6c\u51fa",
#                     "target": "\u4e0a\u6d77_\u8f6c\u5165",
#                     "value": 4458.0
#                 },
#                 {
#                     "source": "\u4e91\u5357_\u8f6c\u51fa",
#                     "target": "\u4e0a\u6d77_\u8f6c\u5165",
#                     "value": 2.0
#                 },
#                 {
#                     "source": "\u5185\u8499\u53e4_\u8f6c\u51fa",
#                     "target": "\u4e0a\u6d77_\u8f6c\u5165",
#                     "value": 8.0
#                 },
#                 {
#                     "source": "\u5317\u4eac_\u8f6c\u51fa",
#                     "target": "\u4e0a\u6d77_\u8f6c\u5165",
#                     "value": 343.0
#                 },
#                 {
#                     "source": "\u5409\u6797_\u8f6c\u51fa",
#                     "target": "\u4e0a\u6d77_\u8f6c\u5165",
#                     "value": 16.0
#                 },
#                 {
#                     "source": "\u56db\u5ddd_\u8f6c\u51fa",
#                     "target": "\u4e0a\u6d77_\u8f6c\u5165",

# %%
##########################################################################################################
## 读取数据、添加列名
##########################################################################################################
trans_net_df = pd.read_excel("D:/CASTED/专利/中间表/zhuanli_data.xlsx", sheet_name = "各省份转移活跃度、净转出地图")

##########################################################################################################
## 绘制各省份转移活跃度热力分布地图
##########################################################################################################
def map_visualmap(trans_net_df) -> Map:
    
    df = trans_net_df
    
    c = (
        Map()
        .add("转移总量", [list(z) for z in zip(df["省份"].tolist(), df["转移总量"].tolist())], "china")
        #.add("净转出量", [list(z) for z in zip(df["省份"].tolist(), df["净转出量"].tolist())], "china")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="各省份转移总量热力分布地图"),
            visualmap_opts=opts.VisualMapOpts(
                                              is_piecewise=True, orient = "vertical", pos_bottom = "10%", pos_left = "5%", 
                                              pieces = [{"max": 4999}, {"min": 5000, "max": 9999}, {"min": 10000, "max": 19999}, 
                                                        {"min": 20000, "max": 39999}, {"min": 40000}]),
            legend_opts = opts.LegendOpts(pos_right = "1%", pos_bottom = "1%", type_ = "scroll"),
        )
    )
    return c

c_Trans_GIS = map_visualmap(trans_net_df)
c_Trans_GIS.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="f6e0aee7aef54d7aaa755adf23fa8774" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_f6e0aee7aef54d7aaa755adf23fa8774 = echarts.init(
#             document.getElementById('f6e0aee7aef54d7aaa755adf23fa8774'), 'white', {renderer: 'canvas'});
#         var option_f6e0aee7aef54d7aaa755adf23fa8774 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u8f6c\u79fb\u603b\u91cf",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 91324
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 52599
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 53248
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 22832
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 18131
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 32999
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 12936
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 18728
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 19076
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 10009
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 12449
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 9785
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 9554
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 11261
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 8224
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 4249
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 8350
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 6269
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 6216
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 3016
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 3421
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 2316
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 3743
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 2332
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 1395
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 3365
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1500
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 1024
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 1022
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 435
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 383
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8f6c\u79fb\u603b\u91cf"
#             ],
#             "selected": {
#                 "\u8f6c\u79fb\u603b\u91cf": true
#             },
#             "type": "scroll",
#             "show": true,
#             "right": "1%",
#             "bottom": "1%"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u7701\u4efd\u8f6c\u79fb\u603b\u91cf\u70ed\u529b\u5206\u5e03\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "5%",
#         "bottom": "10%",
#         "showLabel": true,
#         "pieces": [
#             {
#                 "max": 4999
#             },
#             {
#                 "min": 5000,
#                 "max": 9999
#             },
#             {
#                 "min": 10000,
#                 "max": 19999
#             },
#             {
#                 "min": 20000,
#                 "max": 39999
#             },
#             {
#                 "min": 40000
#             }
#         ]
#     }
# };
#         chart_f6e0aee7aef54d7aaa755adf23fa8774.setOption(option_f6e0aee7aef54d7aaa755adf23fa8774);
#     });
# </script>

# %%
##########################################################################################################
## 读取数据、添加列名
##########################################################################################################
trans_net_df = pd.read_excel("D:/CASTED/专利/中间表/zhuanli_data.xlsx", sheet_name = "各省份转移活跃度、净转出地图")

##########################################################################################################
## 绘制各省份转移活跃度热力分布地图
##########################################################################################################
def map_visualmap(trans_net_df) -> Map:
    
    df = trans_net_df
    
    c = (
        Map()
       # .add("总专利数", [list(z) for z in zip(df["省份"].tolist(), df["转移总量"].tolist())], "china")
        .add("净转出量", [list(z) for z in zip(df["省份"].tolist(), df["净转出量"].tolist())], "china")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="各省份净转出热力分布地图"),
            visualmap_opts=opts.VisualMapOpts(
                                              is_piecewise=True, orient = "vertical", pos_bottom = "10%", pos_left = "5%", 
                                              pieces = [{"max": -3000}, {"min": -2999, "max": -1000}, 
                                                        {"min": -999, "max": 0}, {"min": 1, "max": 1000}, 
                                                        {"min": 1001, "max": 4000}, {"min": 4001}]),
            legend_opts = opts.LegendOpts(pos_right = "1%", pos_bottom = "1%", type_ = "scroll"),
        )
    )
    return c

c_netTrans_GIS = map_visualmap(trans_net_df)
c_netTrans_GIS.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="2c4197c0418b4ba4b529fec24409b04f" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_2c4197c0418b4ba4b529fec24409b04f = echarts.init(
#             document.getElementById('2c4197c0418b4ba4b529fec24409b04f'), 'white', {renderer: 'canvas'});
#         var option_2c4197c0418b4ba4b529fec24409b04f = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u51c0\u8f6c\u51fa\u91cf",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": -12737
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": -1836
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 13277
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 341
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 2401
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 3784
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 3109
#                 },
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 1999
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 2688
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": -450
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": -37
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": -1950
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": -798
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": -2622
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": -1408
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 335
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": -1369
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 67
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": -339
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": -1084
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": -90
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": -235
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": -411
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": -65
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": -183
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": -1505
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": -409
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 15
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": -198
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": -139
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": -151
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u51c0\u8f6c\u51fa\u91cf"
#             ],
#             "selected": {
#                 "\u51c0\u8f6c\u51fa\u91cf": true
#             },
#             "type": "scroll",
#             "show": true,
#             "right": "1%",
#             "bottom": "1%"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u7701\u4efd\u51c0\u8f6c\u51fa\u70ed\u529b\u5206\u5e03\u5730\u56fe"
#         }
#     ],
#     "visualMap": {
#         "type": "piecewise",
#         "min": 0,
#         "max": 100,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "left": "5%",
#         "bottom": "10%",
#         "showLabel": true,
#         "pieces": [
#             {
#                 "max": -3000
#             },
#             {
#                 "min": -2999,
#                 "max": -1000
#             },
#             {
#                 "min": -999,
#                 "max": 0
#             },
#             {
#                 "min": 1,
#                 "max": 1000
#             },
#             {
#                 "min": 1001,
#                 "max": 4000
#             },
#             {
#                 "min": 4001
#             }
#         ]
#     }
# };
#         chart_2c4197c0418b4ba4b529fec24409b04f.setOption(option_2c4197c0418b4ba4b529fec24409b04f);
#     });
# </script>

# %%
##########################################################################################################
## 绘制各省份净转出分布
##########################################################################################################
def bar_horizon(trans_net_df) -> Bar:
    
    df = trans_net_df
    df = df.sort_values(by = "净转出量", ascending = False)
    
    c = (
        Bar(init_opts=opts.InitOpts(width="960px", height="500px"))
        .add_xaxis(df["省份"].tolist())
        .add_yaxis("转移总量", df["专利总量"].tolist(), category_gap="80%", is_selected = False)
        .add_yaxis("净转出量", df["净转出量"].tolist(), category_gap="80%")
        #.reversal_axis()
        .set_series_opts(label_opts=opts.LabelOpts(position="right", is_show = False))
        .set_global_opts(
                         #title_opts=opts.TitleOpts(title="专利总数时间变化趋势（2010-2018年）"), 
                         legend_opts = opts.LegendOpts(pos_right = "1%", pos_bottom = "50%", orient = "vertical", is_show = True), 
                         xaxis_opts=opts.AxisOpts(is_show = True, axislabel_opts=opts.LabelOpts(rotate=45)), 
                         yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)), 
                         datazoom_opts = opts.DataZoomOpts(type_ = "slider", range_start = 0, range_end = 50))
    )
    return c

c_transNet_Bar = bar_horizon(trans_net_df)
c_transNet_Bar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="68d04ddb0f2d42379063e036bf442ba8" style="width:960px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_68d04ddb0f2d42379063e036bf442ba8 = echarts.init(
#             document.getElementById('68d04ddb0f2d42379063e036bf442ba8'), 'white', {renderer: 'canvas'});
#         var option_68d04ddb0f2d42379063e036bf442ba8 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u8f6c\u79fb\u603b\u91cf",
#             "data": [
#                 397428,
#                 185200,
#                 148791,
#                 125675,
#                 186636,
#                 131546,
#                 191498,
#                 63512,
#                 53214,
#                 8205,
#                 101205,
#                 22384,
#                 29872,
#                 3530,
#                 877,
#                 18960,
#                 4843,
#                 28019,
#                 49243,
#                 11423,
#                 22501,
#                 120424,
#                 71452,
#                 32930,
#                 62834,
#                 63843,
#                 12964,
#                 483469,
#                 75382,
#                 65225,
#                 657501
#             ],
#             "barCategoryGap": "80%",
#             "label": {
#                 "show": false,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u51c0\u8f6c\u51fa\u91cf",
#             "data": [
#                 13277,
#                 3784,
#                 3109,
#                 2688,
#                 2401,
#                 1999,
#                 341,
#                 335,
#                 67,
#                 15,
#                 -37,
#                 -65,
#                 -90,
#                 -139,
#                 -151,
#                 -183,
#                 -198,
#                 -235,
#                 -339,
#                 -409,
#                 -411,
#                 -450,
#                 -798,
#                 -1084,
#                 -1369,
#                 -1408,
#                 -1505,
#                 -1836,
#                 -1950,
#                 -2622,
#                 -12737
#             ],
#             "barCategoryGap": "80%",
#             "label": {
#                 "show": false,
#                 "position": "right",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u8f6c\u79fb\u603b\u91cf",
#                 "\u51c0\u8f6c\u51fa\u91cf"
#             ],
#             "selected": {
#                 "\u8f6c\u79fb\u603b\u91cf": false,
#                 "\u51c0\u8f6c\u51fa\u91cf": true
#             },
#             "show": true,
#             "right": "1%",
#             "bottom": "50%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "axisLabel": {
#                 "show": true,
#                 "position": "top",
#                 "rotate": 45,
#                 "margin": 8
#             },
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "\u6d59\u6c5f",
#                 "\u5317\u4eac",
#                 "\u56db\u5ddd",
#                 "\u798f\u5efa",
#                 "\u5b89\u5fbd",
#                 "\u4e0a\u6d77",
#                 "\u5c71\u4e1c",
#                 "\u9655\u897f",
#                 "\u5e7f\u897f",
#                 "\u5b81\u590f",
#                 "\u6e56\u5317",
#                 "\u5409\u6797",
#                 "\u9ed1\u9f99\u6c5f",
#                 "\u9752\u6d77",
#                 "\u897f\u85cf",
#                 "\u7518\u8083",
#                 "\u6d77\u5357",
#                 "\u4e91\u5357",
#                 "\u8fbd\u5b81",
#                 "\u5185\u8499\u53e4",
#                 "\u5c71\u897f",
#                 "\u6cb3\u5357",
#                 "\u5929\u6d25",
#                 "\u8d35\u5dde",
#                 "\u91cd\u5e86",
#                 "\u6c5f\u897f",
#                 "\u65b0\u7586",
#                 "\u6c5f\u82cf",
#                 "\u6e56\u5357",
#                 "\u6cb3\u5317",
#                 "\u5e7f\u4e1c"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": true,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ],
#     "dataZoom": {
#         "show": true,
#         "type": "slider",
#         "realtime": true,
#         "start": 0,
#         "end": 50,
#         "orient": "horizontal",
#         "zoomLock": false
#     }
# };
#         chart_68d04ddb0f2d42379063e036bf442ba8.setOption(option_68d04ddb0f2d42379063e036bf442ba8);
#     });
# </script>

# %% [markdown]
# ## 3.2 北京辐射带动能力最为强劲

# %%
# 用户输入需要查询的省份
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt

##########################################################################################################
## 筛选出指定地区年份的转入、转出数据
##########################################################################################################
@widgets.interact_manual(
    pro = ["北京", "天津", "河北", "山西", "内蒙古", "辽宁", 
           "吉林", "黑龙江", "上海", "江苏", "浙江", "安徽", 
           "福建", "江西", "山东", "河南", "湖北", "湖南", 
           "广东", "广西", "海南", "重庆", "四川", "贵州", 
           "云南", "西藏", "陕西", "甘肃", "青海", "宁夏", 
           "新疆", "台湾", "香港", "澳门"], 
    year = ["2010年", "2011年", "2012年", "2013年", "2014年", "2015年", "2016年", "2017年", "2018年"])


def geo_lines(pro = "北京", year = "2018年", local_included = True) -> Geo:
    
    def trans_city(pro, year, local_included = True):
        global path
        
        trans_df = pd.read_excel(path, sheet_name = "trans")
        trans_df.columns = ["转出", "转入", "2010年", "2011年", "2012年", "2013年", "2014年", "2015年", "2016年", "2017年", "2018年"]
    
        trans_df = trans_df.groupby(['转出', '转入']).sum().reset_index()
        def cleanFilter(item):
            province = ["北京", "天津", "河北", "山西", "内蒙古", "辽宁", 
                        "吉林", "黑龙江", "上海", "江苏", "浙江", "安徽", 
                        "福建", "江西", "山东", "河南", "湖北", "湖南", 
                        "广东", "广西", "海南", "重庆", "四川", "贵州", 
                        "云南", "西藏", "陕西", "甘肃", "青海", "宁夏", 
                        "新疆", "台湾", "香港", "澳门"]
    
            if item in province:
                index = True
            else:
                index = False
            return index

        trans_df = trans_df[(trans_df["转出"].map(cleanFilter)) & (trans_df["转入"].map(cleanFilter))]
    
    
        trans_out = trans_df[trans_df["转出"] == pro][["转出", "转入", year]]
        trans_out_name = trans_out.columns.tolist()
        trans_out_name[2] = "专利转移数量"
        trans_out.columns = trans_out_name
        trans_in = trans_df[trans_df["转入"] == pro][["转出", "转入", year]]
        trans_in_name = trans_in.columns.tolist()
        trans_in_name[2] = "专利转移数量"
        trans_in.columns = trans_in_name
    
        if not local_included:
            trans_out = trans_out[trans_out["转入"] != pro]
            trans_in = trans_in[trans_in["转出"] != pro]

        return trans_out, trans_in
    
    
    df_out, df_in = trans_city(pro, year, local_included)
    
    c = (
        Geo()
        .add_schema(maptype="china")
        .add(
            "转出",
            list(zip(df_out["转入"].tolist(), df_out["专利转移数量"].tolist())),
            type_=ChartType.HEATMAP,
            #color="white",
        )
        .add(
            "转出",
            list(zip(df_out["转出"].tolist(), df_out["转入"].tolist())),
            type_=ChartType.LINES,
            #effect_opts=opts.EffectOpts(
            #    symbol=SymbolType.ARROW, symbol_size=6, color="blue"
            #),
            linestyle_opts=opts.LineStyleOpts(curve=0.2),
        )
        .add(
            "转入",
            list(zip(df_in["转出"].tolist(), df_in["专利转移数量"].tolist())),
            type_=ChartType.HEATMAP,
            #color="white",
            is_selected = False, 
        )
        .add(
            "转入",
            list(zip(df_in["转出"].tolist(), df_in["转入"].tolist())),
            type_=ChartType.LINES,
            #effect_opts=opts.EffectOpts(
            #    symbol=SymbolType.ARROW, symbol_size=6, color="blue"
            #),
            linestyle_opts=opts.LineStyleOpts(curve=0.2),
            is_selected = False, 
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(orient = "horizontal", pos_bottom = "10%", pos_left = "10%"),
            title_opts=opts.TitleOpts(title="专利转移辐射图"), 
        )
    )

    return c.render_notebook()
# Out:
# interactive(children=(Dropdown(description='pro', options=('北京', '天津', '河北', '山西', '内蒙古', '辽宁', '吉林', '黑龙江', '…

# %%
# 用户输入需要查询的省份
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt

##########################################################################################################
## 筛选出指定地区年份的转入、转出数据
##########################################################################################################
@widgets.interact_manual(
    pro = ["北京", "天津", "河北", "山西", "内蒙古", "辽宁", 
           "吉林", "黑龙江", "上海", "江苏", "浙江", "安徽", 
           "福建", "江西", "山东", "河南", "湖北", "湖南", 
           "广东", "广西", "海南", "重庆", "四川", "贵州", 
           "云南", "西藏", "陕西", "甘肃", "青海", "宁夏", 
           "新疆", "台湾", "香港", "澳门"], 
    year = ["2010年", "2011年", "2012年", "2013年", "2014年", "2015年", "2016年", "2017年", "2018年"])


def geo_lines(pro = "北京", year = "2018年", local_included = True) -> Geo:
    
    def trans_city(pro, year, local_included):
        global path
        
        trans_df = pd.read_excel(path, sheet_name = "trans")
        trans_df.columns = ["转出", "转入", "2010年", "2011年", "2012年", "2013年", "2014年", "2015年", "2016年", "2017年", "2018年"]
    
        trans_df = trans_df.groupby(['转出', '转入']).sum().reset_index()
        def cleanFilter(item):
            province = ["北京", "天津", "河北", "山西", "内蒙古", "辽宁", 
                        "吉林", "黑龙江", "上海", "江苏", "浙江", "安徽", 
                        "福建", "江西", "山东", "河南", "湖北", "湖南", 
                        "广东", "广西", "海南", "重庆", "四川", "贵州", 
                        "云南", "西藏", "陕西", "甘肃", "青海", "宁夏", 
                        "新疆", "台湾", "香港", "澳门"]
    
            if item in province:
                index = True
            else:
                index = False
            return index

        trans_df = trans_df[(trans_df["转出"].map(cleanFilter)) & (trans_df["转入"].map(cleanFilter))]
    
    
        trans_out = trans_df[trans_df["转出"] == pro][["转出", "转入", year]]
        trans_out_name = trans_out.columns.tolist()
        trans_out_name[2] = "专利转移数量"
        trans_out.columns = trans_out_name
        trans_in = trans_df[trans_df["转入"] == pro][["转出", "转入", year]]
        trans_in_name = trans_in.columns.tolist()
        trans_in_name[2] = "专利转移数量"
        trans_in.columns = trans_in_name
    
        if not local_included:
            trans_out = trans_out[trans_out["转入"] != pro]
            trans_in = trans_in[trans_in["转出"] != pro]

        return trans_out, trans_in
    
    
    df_out, df_in = trans_city(pro, year, local_included)
    df_bar = pd.merge(df_out, df_in, how = 'inner', left_on = "转入", right_on = "转出", 
                  suffixes=('_由', '_到'))[["转入_由", "专利转移数量_由", "专利转移数量_到"]]
    df_bar.columns = ["省份", "转出", "转入"]
    df_bar = df_bar.sort_values(by = ["转出"], ascending = False)
    
    c_bar = (
        Bar()
        .add_xaxis(df_bar["省份"].tolist())
        .add_yaxis("转出", df_bar["转出"].tolist())
        .add_yaxis("转入", df_bar["转入"].tolist(), is_selected=False, category_gap="80%")
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="北京市卖出专利流向省市规模对比（2018年）"), 
                         legend_opts = opts.LegendOpts(pos_right = "1%", pos_top = "15%", orient = "vertical"), 
                         #datazoom_opts = opts.DataZoomOpts(type_ = "inside", range_start = 0, range_end = 40), 
                        )
    )
    
    return c_bar.render_notebook()
# Out:
# interactive(children=(Dropdown(description='pro', options=('北京', '天津', '河北', '山西', '内蒙古', '辽宁', '吉林', '黑龙江', '…

# %%
# 用户输入需要查询的省份
import ipywidgets as widgets
from IPython.display import display
import numpy as np
import matplotlib.pyplot as plt

##########################################################################################################
## 筛选出指定地区年份的转入、转出数据
##########################################################################################################
@widgets.interact_manual(
    pro = ["北京", "天津", "河北", "山西", "内蒙古", "辽宁", 
           "吉林", "黑龙江", "上海", "江苏", "浙江", "安徽", 
           "福建", "江西", "山东", "河南", "湖北", "湖南", 
           "广东", "广西", "海南", "重庆", "四川", "贵州", 
           "云南", "西藏", "陕西", "甘肃", "青海", "宁夏", 
           "新疆", "台湾", "香港", "澳门"], 
    year = ["2010年", "2011年", "2012年", "2013年", "2014年", "2015年", "2016年", "2017年", "2018年"])


def geo_lines(pro = "北京", year = "2018年", local_included = True) -> Geo:
    
    def trans_city(pro, year, local_included):
        global path
        
        trans_df = pd.read_excel(path, sheet_name = "trans")
        trans_df.columns = ["转出", "转入", "2010年", "2011年", "2012年", "2013年", "2014年", "2015年", "2016年", "2017年", "2018年"]
    
        trans_df = trans_df.groupby(['转出', '转入']).sum().reset_index()
        def cleanFilter(item):
            province = ["北京", "天津", "河北", "山西", "内蒙古", "辽宁", 
                        "吉林", "黑龙江", "上海", "江苏", "浙江", "安徽", 
                        "福建", "江西", "山东", "河南", "湖北", "湖南", 
                        "广东", "广西", "海南", "重庆", "四川", "贵州", 
                        "云南", "西藏", "陕西", "甘肃", "青海", "宁夏", 
                        "新疆", "台湾", "香港", "澳门"]
    
            if item in province:
                index = True
            else:
                index = False
            return index

        trans_df = trans_df[(trans_df["转出"].map(cleanFilter)) & (trans_df["转入"].map(cleanFilter))]
    
    
        trans_out = trans_df[trans_df["转出"] == pro][["转出", "转入", year]]
        trans_out_name = trans_out.columns.tolist()
        trans_out_name[2] = "专利转移数量"
        trans_out.columns = trans_out_name
        trans_in = trans_df[trans_df["转入"] == pro][["转出", "转入", year]]
        trans_in_name = trans_in.columns.tolist()
        trans_in_name[2] = "专利转移数量"
        trans_in.columns = trans_in_name
    
        if not local_included:
            trans_out = trans_out[trans_out["转入"] != pro]
            trans_in = trans_in[trans_in["转出"] != pro]

        return trans_out, trans_in
    
    
    df_out, df_in = trans_city(pro, year, local_included)
    
    df_net = pd.merge(df_out, df_in, how = 'inner', left_on = "转入", right_on = "转出", suffixes=('_由', '_到'))
    df_net["net"] = df_net["专利转移数量_由"] - df_net["专利转移数量_到"]
    df_net = df_net[["转出_由", "转入_由", "net"]]
    df_net.columns = ["转出", "转入", "净转出"]
    
    
    c = (
        Geo()
        .add_schema(maptype="china")
        .add(
            "净转出",
            list(zip(df_net["转入"].tolist(), df_net["净转出"].abs().tolist())),
            type_=ChartType.HEATMAP,
            #color="white",
        )
        .add(
            "净转出",
            list(zip(df_net["转出"][df_net["净转出"] > 0].tolist(), df_net["转入"][df_net["净转出"] > 0].tolist())),
            type_=ChartType.LINES,
            #effect_opts=opts.EffectOpts(
            #    symbol=SymbolType.ARROW, symbol_size=6, color="blue"
            #),
            linestyle_opts=opts.LineStyleOpts(curve=0.2),
        )
        .add(
            "净转入",
            list(zip(df_net["转入"][df_net["净转出"] < 0].tolist(), df_net["转出"][df_net["净转出"] < 0].tolist())),
            type_=ChartType.LINES,
            #effect_opts=opts.EffectOpts(
            #    symbol=SymbolType.ARROW, symbol_size=6, color="blue"
            #),
            linestyle_opts=opts.LineStyleOpts(curve=0.2),
            is_selected = True, 
        )
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            visualmap_opts=opts.VisualMapOpts(orient = "horizontal", pos_bottom = "10%", pos_left = "10%"),
            title_opts=opts.TitleOpts(title="专利转移辐射图"), 
        )
    )
    return c.render_notebook()
# Out:
# interactive(children=(Dropdown(description='pro', options=('北京', '天津', '河北', '山西', '内蒙古', '辽宁', '吉林', '黑龙江', '…

# %% [markdown]
# # 三、全国人工智能重点领域创新现状
# ## 3.1各领域整体数量分布对比（2010-2018年）

# %%
industry_df  = pd.read_excel(path, sheet_name = "领域-十年行业占比饼环图")
industry_df.columns = ["二级分类", "三级分类", "专利数"]

class_df = industry_df.groupby(['二级分类']).sum().reset_index().sort_values(by = ["专利数"], ascending = True)
class_df["百分比"] = (class_df["专利数"] / class_df["专利数"].sum() * 100).round(2)
class_df = class_df.sort_values(by = ["百分比"], ascending = False)

##########################################################################################################
## 绘制专利数种类占比饼图
##########################################################################################################
def pie_radius(class_df) -> Pie:
    
    df = class_df
    
    c = (
        Pie(init_opts=opts.InitOpts())
        .add(
            "",
            [list(z) for z in zip(df["二级分类"].tolist(), df["百分比"].tolist())],
            radius=["30%", "45%"],
            is_clockwise = False, 
            center = ["50%", "50%"]
        )
        .set_global_opts(
            title_opts=opts.TitleOpts(title="各产业整体数量分布对比（2010-2018年）"),
            legend_opts=opts.LegendOpts(
                orient="vertical", pos_top="15%", pos_left="2%"
            ),
        )
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}: {c}%"))
        )
             
    return c

c_classPie = pie_radius(class_df)
c_classPie.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="5647cc998b1b428ea73447af485f9a04" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_5647cc998b1b428ea73447af485f9a04 = echarts.init(
#             document.getElementById('5647cc998b1b428ea73447af485f9a04'), 'white', {renderer: 'canvas'});
#         var option_5647cc998b1b428ea73447af485f9a04 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "pie",
#             "clockwise": false,
#             "data": [
#                 {
#                     "name": "\u5e94\u7528\u5c42",
#                     "value": 67.75
#                 },
#                 {
#                     "name": "\u6838\u5fc3\u5c42",
#                     "value": 29.17
#                 },
#                 {
#                     "name": "\u5176\u5b83",
#                     "value": 2.96
#                 },
#                 {
#                     "name": "\u57fa\u7840\u5c42",
#                     "value": 0.12
#                 }
#             ],
#             "radius": [
#                 "30%",
#                 "45%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8,
#                 "formatter": "{b}: {c}%"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u5e94\u7528\u5c42",
#                 "\u6838\u5fc3\u5c42",
#                 "\u5176\u5b83",
#                 "\u57fa\u7840\u5c42"
#             ],
#             "selected": {},
#             "show": true,
#             "left": "2%",
#             "top": "15%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "title": [
#         {
#             "text": "\u5404\u4ea7\u4e1a\u6574\u4f53\u6570\u91cf\u5206\u5e03\u5bf9\u6bd4\uff082010-2018\u5e74\uff09"
#         }
#     ]
# };
#         chart_5647cc998b1b428ea73447af485f9a04.setOption(option_5647cc998b1b428ea73447af485f9a04);
#     });
# </script>

# %% [markdown]
# ## 3.2专利总量及各领域时间变化趋势（2010-2018年）

# %%
total_year_df = pd.read_excel(path, sheet_name = "领域-专利总数时间变化趋势（2010-2018年）")
total_year_df.loc["专利总量", :] = total_year_df.sum()
total_year_df.set_index("二级产业", inplace = True)

index = total_year_df.index.tolist()
index[4] = "专利总量"
total_year_df.index = index

##########################################################################################################
## 绘制专利总量逐年变化趋势
##########################################################################################################
def bar_horizon(total_year_df) -> Bar:
    
    df = total_year_df
    
    c = (
        Bar(init_opts=opts.InitOpts(width="960px", height="400px"))
        .add_xaxis(df.columns.tolist())
        .add_yaxis("专利总量", df.loc["专利总量", :].tolist(), category_gap="80%")
        .set_series_opts(label_opts=opts.LabelOpts(position="top"))
        .set_global_opts(
                         #title_opts=opts.TitleOpts(title="专利总数时间变化趋势（2010-2018年）"), 
                         legend_opts = opts.LegendOpts(pos_right = "1%", pos_bottom = "50%", orient = "vertical", is_show = False), 
                         xaxis_opts=opts.AxisOpts(is_show = True))
    )
    return c

c_totalyearBar = bar_horizon(total_year_df)
c_totalyearBar.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="427d85eb753046df865cff30e0ba1091" style="width:960px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_427d85eb753046df865cff30e0ba1091 = echarts.init(
#             document.getElementById('427d85eb753046df865cff30e0ba1091'), 'white', {renderer: 'canvas'});
#         var option_427d85eb753046df865cff30e0ba1091 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u4e13\u5229\u603b\u91cf",
#             "data": [
#                 16478.0,
#                 20152.0,
#                 29804.0,
#                 40855.0,
#                 45705.0,
#                 69658.0,
#                 90270.0,
#                 123575.0,
#                 172037.0
#             ],
#             "barCategoryGap": "80%",
#             "label": {
#                 "show": true,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u4e13\u5229\u603b\u91cf"
#             ],
#             "selected": {
#                 "\u4e13\u5229\u603b\u91cf": true
#             },
#             "show": false,
#             "right": "1%",
#             "bottom": "50%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 2010,
#                 2011,
#                 2012,
#                 2013,
#                 2014,
#                 2015,
#                 2016,
#                 2017,
#                 2018
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ]
# };
#         chart_427d85eb753046df865cff30e0ba1091.setOption(option_427d85eb753046df865cff30e0ba1091);
#     });
# </script>

# %%
rate_year_df = pd.read_excel(path, sheet_name = "领域-各产业逐年增长率时间变化趋势")
rate_year_df.set_index("二级产业", inplace = True)

##########################################################################################################
## 绘制各产业逐年增长率时间变化趋势
##########################################################################################################
def line_base(rate_year_df) -> Line:
    
    df = rate_year_df
    
    c = (
        Line(init_opts=opts.InitOpts(width="960px", height="400px"))
        .add_xaxis([str(x) for x in df.columns.tolist()])
        .add_yaxis("基础层", df.loc['基础层', :].tolist())
        .add_yaxis("核心层", df.loc['核心层', :].tolist())
        .add_yaxis("应用层", df.loc['应用层', :].tolist())
        .add_yaxis("其它", df.loc['其它', :].tolist())
        .set_series_opts(label_opts=opts.LabelOpts(is_show = False), 
                         # markline_opts=opts.MarkLineOpts(data=[opts.MarkLineItem(x = "2016")]),
                                                               )
        .set_global_opts(title_opts=opts.TitleOpts(title=""), 
                         yaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(formatter="{value}%")), 
                         legend_opts = opts.LegendOpts(pos_right = "1%", pos_top = "1%", orient = "horizontal", is_show = True))
    )
    return c

c_rateLine = line_base(rate_year_df)
c_rateLine.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="6d6ed63023f24e4991bd4ff74ca6083a" style="width:960px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_6d6ed63023f24e4991bd4ff74ca6083a = echarts.init(
#             document.getElementById('6d6ed63023f24e4991bd4ff74ca6083a'), 'white', {renderer: 'canvas'});
#         var option_6d6ed63023f24e4991bd4ff74ca6083a = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "line",
#             "name": "\u57fa\u7840\u5c42",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010",
#                     NaN
#                 ],
#                 [
#                     "2011",
#                     -14.2857142857143
#                 ],
#                 [
#                     "2012",
#                     -11.1111111111111
#                 ],
#                 [
#                     "2013",
#                     268.75
#                 ],
#                 [
#                     "2014",
#                     38.9830508474576
#                 ],
#                 [
#                     "2015",
#                     -23.1707317073171
#                 ],
#                 [
#                     "2016",
#                     69.8412698412698
#                 ],
#                 [
#                     "2017",
#                     22.4299065420561
#                 ],
#                 [
#                     "2018",
#                     96.9465648854962
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u6838\u5fc3\u5c42",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010",
#                     NaN
#                 ],
#                 [
#                     "2011",
#                     21.4317277949624
#                 ],
#                 [
#                     "2012",
#                     49.6360989810771
#                 ],
#                 [
#                     "2013",
#                     39.9197470817121
#                 ],
#                 [
#                     "2014",
#                     21.7172156078909
#                 ],
#                 [
#                     "2015",
#                     41.5322004855062
#                 ],
#                 [
#                     "2016",
#                     20.3147858548151
#                 ],
#                 [
#                     "2017",
#                     53.2033542976939
#                 ],
#                 [
#                     "2018",
#                     46.4708941131394
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5e94\u7528\u5c42",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010",
#                     NaN
#                 ],
#                 [
#                     "2011",
#                     22.8322672352523
#                 ],
#                 [
#                     "2012",
#                     46.9694777954578
#                 ],
#                 [
#                     "2013",
#                     37.6624015748031
#                 ],
#                 [
#                     "2014",
#                     7.72888142137061
#                 ],
#                 [
#                     "2015",
#                     58.4868093578895
#                 ],
#                 [
#                     "2016",
#                     34.1687604690117
#                 ],
#                 [
#                     "2017",
#                     30.6699542751916
#                 ],
#                 [
#                     "2018",
#                     35.2015955668084
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "line",
#             "name": "\u5176\u5b83",
#             "connectNulls": false,
#             "symbolSize": 4,
#             "showSymbol": true,
#             "smooth": false,
#             "step": false,
#             "data": [
#                 [
#                     "2010",
#                     NaN
#                 ],
#                 [
#                     "2011",
#                     20.2962962962963
#                 ],
#                 [
#                     "2012",
#                     53.2019704433498
#                 ],
#                 [
#                     "2013",
#                     5.78778135048232
#                 ],
#                 [
#                     "2014",
#                     12.6139817629179
#                 ],
#                 [
#                     "2015",
#                     35.7624831309042
#                 ],
#                 [
#                     "2016",
#                     11.0337972166998
#                 ],
#                 [
#                     "2017",
#                     42.0322291853178
#                 ],
#                 [
#                     "2018",
#                     59.2499212102112
#                 ]
#             ],
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "lineStyle": {
#                 "width": 1,
#                 "opacity": 1,
#                 "curveness": 0,
#                 "type": "solid"
#             },
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u57fa\u7840\u5c42",
#                 "\u

# %%
compete_df = pd.read_excel(path, sheet_name = "领域-2017年各行业竞争对比气泡图")
compete_df.set_index("二级产业", inplace = True)

##########################################################################################################
## 绘制2017年各行业竞争对比气泡图
##########################################################################################################
def scatter_visualmap_color(compete_df) -> Scatter:
    
    df = compete_df
    
    c = (
        Scatter(init_opts=opts.InitOpts(width="960px", height="400px"))
        .add_xaxis([str(x) for x in df["专利数"].tolist()])
        #.add_yaxis("", df["平均增长率"].round(2).tolist())
        .add_yaxis("基础层", df["基础层"].tolist())
        .add_yaxis("核心层", df["核心层"].tolist())
        .add_yaxis("应用层", df["应用层"].tolist())
        .add_yaxis("其它", df["其它"].tolist())
        .set_global_opts(
            #title_opts=opts.TitleOpts(title="2017年各行业竞争对比"),
            xaxis_opts=opts.AxisOpts(type_ = "value"),
            yaxis_opts=opts.AxisOpts(is_scale = True),
            visualmap_opts=opts.VisualMapOpts(type_="size", min_ = 18, max_ = 30),
            legend_opts = opts.LegendOpts(is_show = False),
        )
        .set_series_opts(label_opts=opts.LabelOpts(formatter="{a}", position="right"))
    )
    return c

c_bubble = scatter_visualmap_color(compete_df)
c_bubble.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="7eec4a6642704b7fbc4da99bfbb2e50e" style="width:960px; height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_7eec4a6642704b7fbc4da99bfbb2e50e = echarts.init(
#             document.getElementById('7eec4a6642704b7fbc4da99bfbb2e50e'), 'white', {renderer: 'canvas'});
#         var option_7eec4a6642704b7fbc4da99bfbb2e50e = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "scatter",
#             "name": "\u57fa\u7840\u5c42",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "755",
#                     56.0479043765172
#                 ],
#                 [
#                     "177490",
#                     NaN
#                 ],
#                 [
#                     "412288",
#                     NaN
#                 ],
#                 [
#                     "18001",
#                     NaN
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u6838\u5fc3\u5c42",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "755",
#                     NaN
#                 ],
#                 [
#                     "177490",
#                     36.7782530270996
#                 ],
#                 [
#                     "412288",
#                     NaN
#                 ],
#                 [
#                     "18001",
#                     NaN
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5e94\u7528\u5c42",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "755",
#                     NaN
#                 ],
#                 [
#                     "177490",
#                     NaN
#                 ],
#                 [
#                     "412288",
#                     34.2150184619731
#                 ],
#                 [
#                     "18001",
#                     NaN
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "scatter",
#             "name": "\u5176\u5b83",
#             "symbolSize": 10,
#             "data": [
#                 [
#                     "755",
#                     NaN
#                 ],
#                 [
#                     "177490",
#                     NaN
#                 ],
#                 [
#                     "412288",
#                     NaN
#                 ],
#                 [
#                     "18001",
#                     29.9973075745224
#                 ]
#             ],
#             "label": {
#                 "show": true,
#                 "position": "right",
#                 "margin": 8,
#                 "formatter": "{a}"
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u57fa\u7840\u5c42",
#                 "\u6838\u5fc3\u5c42",
#                 "\u5e94\u7528\u5c42",
#                 "\u5176\u5b83"
#             ],
#             "selected": {
#                 "\u57fa\u7840\u5c42": true,
#                 "\u6838\u5fc3\u5c42": true,
#                 "\u5e94\u7528\u5c42": true,
#                 "\u5176\u5b83": true
#             },
#             "show": false
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {
#             "type": "value",
#             "show": true,
#             "scale": false,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             },
#             "data": [
#                 "755",
#                 "177490",
#                 "412288",
#                 "18001"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "scale": true,
#             "nameLocation": "end",
#             "nameGap": 15,
#             "gridIndex": 0,
#             "inverse": false,
#             "offset": 0,
#             "splitNumber": 5,
#             "minInterval": 0,
#             "splitLine": {
#                 "show": false,
#                 "lineStyle": {
#                     "width": 1,
#                     "opacity": 1,
#                     "curveness": 0,
#                     "type": "solid"
#                 }
#             }
#         }
#     ],
#     "title": [
#         {}
#     ],
#     "visualMap": {
#         "type": "continuous",
#         "min": 18,
#         "max": 30,
#         "inRange": {
#             "symbolSize": [
#                 20,
#                 50
#             ]
#         },
#         "calculable": true,
#         "splitNumber": 5,
#         "orient": "vertical",
#         "showLabel": true
#     }
# };
#         chart_7eec4a6642704b7fbc4da99bfbb2e50e.setOption(option_7eec4a6642704b7fbc4da99bfbb2e50e);
#     });
# </script>

# %% [markdown]
# ## 3.3各领域区域分部特点（2010-2018年)

# %%
pro_df  = pd.read_excel(path, sheet_name = "领域-省级行政区区域各产业专利规模")

pro_df = pro_df.reset_index()

col_name = pro_df.columns.tolist()
col_name[0] = "省份"
col_name[5] = "总专利数"
pro_df.columns = col_name

##########################################################################################################
## 绘制专利数省份柱状分布地图
##########################################################################################################

def bar_stack(pro_df) -> Bar:
    
    df = pro_df.sort_values(by = "总专利数", ascending = False)
    
    c = (
        Bar()
        .add_xaxis(df["省份"].tolist())
        .add_yaxis("总专利数", df["总专利数"].tolist())
        .add_yaxis("应用层", df["应用层"].tolist())
        .add_yaxis("核心层", df["核心层"].tolist())
        .add_yaxis("基础层", df["基础层"].tolist())
        .add_yaxis("其它", df["其它"].tolist(), is_selected=False)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(title_opts=opts.TitleOpts(title="省级行政区区域各产业专利规模"), 
                         legend_opts = opts.LegendOpts(pos_right = "1%", pos_top = "15%", orient = "vertical"), 
                         datazoom_opts = opts.DataZoomOpts(type_ = "slider", range_start = 0, range_end = 50))
    )
    return c

c_bar_pro = bar_stack(pro_df)
c_bar_pro.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#     <div id="0009f7fc409d45989933a826393214fc" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#         var chart_0009f7fc409d45989933a826393214fc = echarts.init(
#             document.getElementById('0009f7fc409d45989933a826393214fc'), 'white', {renderer: 'canvas'});
#         var option_0009f7fc409d45989933a826393214fc = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "bar",
#             "name": "\u603b\u4e13\u5229\u6570",
#             "data": [
#                 108468,
#                 76919,
#                 73730,
#                 44853,
#                 38148,
#                 30598,
#                 28521,
#                 25079,
#                 19877,
#                 18740,
#                 17462,
#                 15835,
#                 14797,
#                 13914,
#                 12547,
#                 10946,
#                 9437,
#                 8273,
#                 7579,
#                 6275,
#                 4874,
#                 4081,
#                 3169,
#                 2945,
#                 2884,
#                 1973,
#                 1710,
#                 1592,
#                 1112,
#                 706,
#                 476,
#                 465,
#                 390,
#                 107,
#                 25
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5e94\u7528\u5c42",
#             "data": [
#                 75325,
#                 53179,
#                 41367,
#                 31786,
#                 24815,
#                 22911,
#                 18978,
#                 18643,
#                 12120,
#                 12404,
#                 11761,
#                 11072,
#                 10574,
#                 10449,
#                 8619,
#                 7055,
#                 6101,
#                 6413,
#                 5564,
#                 4214,
#                 3234,
#                 2904,
#                 2308,
#                 2056,
#                 2036,
#                 1457,
#                 1317,
#                 1268,
#                 880,
#                 464,
#                 325,
#                 288,
#                 278,
#                 89,
#                 8
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u6838\u5fc3\u5c42",
#             "data": [
#                 29953,
#                 21321,
#                 29732,
#                 11580,
#                 12161,
#                 6656,
#                 8831,
#                 5742,
#                 7325,
#                 5731,
#                 5148,
#                 4319,
#                 3706,
#                 2947,
#                 3598,
#                 3612,
#                 3100,
#                 1684,
#                 1817,
#                 1876,
#                 1510,
#                 1050,
#                 782,
#                 677,
#                 784,
#                 420,
#                 343,
#                 292,
#                 205,
#                 196,
#                 123,
#                 166,
#                 72,
#                 14,
#                 17
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u57fa\u7840\u5c42",
#             "data": [
#                 178,
#                 85,
#                 107,
#                 48,
#                 37,
#                 37,
#                 34,
#                 41,
#                 22,
#                 16,
#                 23,
#                 17,
#                 23,
#                 12,
#                 8,
#                 10,
#                 13,
#                 7,
#                 6,
#                 2,
#                 6,
#                 1,
#                 5,
#                 1,
#                 5,
#                 3,
#                 4,
#                 0,
#                 1,
#                 2,
#                 1,
#                 0,
#                 0,
#                 0,
#                 0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "bar",
#             "name": "\u5176\u5b83",
#             "data": [
#                 3012,
#                 2334,
#                 2524,
#                 1439,
#                 1135,
#                 994,
#                 678,
#                 653,
#                 410,
#                 589,
#                 530,
#                 427,
#                 494,
#                 506,
#                 322,
#                 269,
#                 223,
#                 169,
#                 192,
#                 183,
#                 124,
#                 126,
#                 74,
#                 211,
#                 59,
#                 93,
#                 46,
#                 32,
#                 26,
#                 44,
#                 27,
#                 11,
#                 40,
#                 4,
#                 0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "\u603b\u4e13\u5229\u6570",
#                 "\u5e94\u7528\u5c42",
#                 "\u6838\u5fc3\u5c42",
#                 "\u57fa\u7840\u5c42",
#                 "\u5176\u5b83"
#             ],
#             "selected": {
#                 "\u603b\u4e13\u5229\u6570": true,
#                 "\u5e94\u7528\u5c42": true,
#                 "\u6838\u5fc3\u5c42": true,
#                 "\u57fa\u7840\u5c42": true,
#                 "\u5176\u5b83": false
#             },
#             "show": true,
#             "right": "1%",
#             "top": "15%",
#             "orient": "vertical"
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0
#     },
#     "xAxis": [
#         {

# %%
##########################################################################################################
## 绘制专利数省份热力分布地图
##########################################################################################################

def map_visualmap(pro_df) -> Map:
    
    df = pro_df
    
    c = (
        Map()
        .add("总专利数", [list(z) for z in zip(df["省份"].tolist(), df["总专利数"].tolist())], "china")
        .add("应用层", [list(z) for z in zip(df["省份"].tolist(), df["应用层"].tolist())], "china", is_selected=False)
        .add("核心层", [list(z) for z in zip(df["省份"].tolist(), df["核心层"].tolist())], "china", is_selected=False)
        .add("基础层", [list(z) for z in zip(df["省份"].tolist(), df["基础层"].tolist())], "china", is_selected=False)
        .add("其它", [list(z) for z in zip(df["省份"].tolist(), df["其它"].tolist())], "china", is_selected=False)
        .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="省级行政区区域各产业专利规模"),
            visualmap_opts=opts.VisualMapOpts(max_=df["总专利数"].max().tolist(), is_piecewise=False, orient = "horizontal", pos_bottom = "10%", pos_left = "5%"),
            legend_opts = opts.LegendOpts(pos_right = "1%", pos_bottom = "1%", type_ = "scroll"),
        )
    )
    return c

c_map_GIS = map_visualmap(pro_df)
c_map_GIS.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#     <div id="c8a03984f48f478bbd6bcd623092ba63" style="width:900px; height:500px;"></div>
#
#
# <script>
#     require(['echarts', 'china'], function(echarts) {
#         var chart_c8a03984f48f478bbd6bcd623092ba63 = echarts.init(
#             document.getElementById('c8a03984f48f478bbd6bcd623092ba63'), 'white', {renderer: 'canvas'});
#         var option_c8a03984f48f478bbd6bcd623092ba63 = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "name": "\u603b\u4e13\u5229\u6570",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 38148
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 4081
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 2945
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1592
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 73730
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 476
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 4874
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 28521
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 17462
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 1112
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 25079
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 30598
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 3169
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 108468
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 7579
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 1710
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 76919
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "value": 6275
#                 },
#                 {
#                     "name": "\u6cb3\u5317",
#                     "value": 8273
#                 },
#                 {
#                     "name": "\u6cb3\u5357",
#                     "value": 13914
#                 },
#                 {
#                     "name": "\u6d59\u6c5f",
#                     "value": 44853
#                 },
#                 {
#                     "name": "\u6d77\u5357",
#                     "value": 706
#                 },
#                 {
#                     "name": "\u6e56\u5317",
#                     "value": 18740
#                 },
#                 {
#                     "name": "\u6e56\u5357",
#                     "value": 12547
#                 },
#                 {
#                     "name": "\u6fb3\u95e8",
#                     "value": 25
#                 },
#                 {
#                     "name": "\u7518\u8083",
#                     "value": 1973
#                 },
#                 {
#                     "name": "\u798f\u5efa",
#                     "value": 14797
#                 },
#                 {
#                     "name": "\u897f\u85cf",
#                     "value": 107
#                 },
#                 {
#                     "name": "\u8d35\u5dde",
#                     "value": 2884
#                 },
#                 {
#                     "name": "\u8fbd\u5b81",
#                     "value": 15835
#                 },
#                 {
#                     "name": "\u91cd\u5e86",
#                     "value": 10946
#                 },
#                 {
#                     "name": "\u9655\u897f",
#                     "value": 19877
#                 },
#                 {
#                     "name": "\u9752\u6d77",
#                     "value": 465
#                 },
#                 {
#                     "name": "\u9999\u6e2f",
#                     "value": 390
#                 },
#                 {
#                     "name": "\u9ed1\u9f99\u6c5f",
#                     "value": 9437
#                 }
#             ],
#             "roam": true,
#             "zoom": 1,
#             "showLegendSymbol": true,
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         },
#         {
#             "type": "map",
#             "name": "\u5e94\u7528\u5c42",
#             "label": {
#                 "show": false,
#                 "position": "top",
#                 "margin": 8
#             },
#             "mapType": "china",
#             "data": [
#                 {
#                     "name": "\u4e0a\u6d77",
#                     "value": 24815
#                 },
#                 {
#                     "name": "\u4e91\u5357",
#                     "value": 2904
#                 },
#                 {
#                     "name": "\u5176\u4ed6",
#                     "value": 2056
#                 },
#                 {
#                     "name": "\u5185\u8499\u53e4",
#                     "value": 1268
#                 },
#                 {
#                     "name": "\u5317\u4eac",
#                     "value": 41367
#                 },
#                 {
#                     "name": "\u53f0\u6e7e",
#                     "value": 325
#                 },
#                 {
#                     "name": "\u5409\u6797",
#                     "value": 3234
#                 },
#                 {
#                     "name": "\u56db\u5ddd",
#                     "value": 18978
#                 },
#                 {
#                     "name": "\u5929\u6d25",
#                     "value": 11761
#                 },
#                 {
#                     "name": "\u5b81\u590f",
#                     "value": 880
#                 },
#                 {
#                     "name": "\u5b89\u5fbd",
#                     "value": 18643
#                 },
#                 {
#                     "name": "\u5c71\u4e1c",
#                     "value": 22911
#                 },
#                 {
#                     "name": "\u5c71\u897f",
#                     "value": 2308
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c",
#                     "value": 75325
#                 },
#                 {
#                     "name": "\u5e7f\u897f",
#                     "value": 5564
#                 },
#                 {
#                     "name": "\u65b0\u7586",
#                     "value": 1317
#                 },
#                 {
#                     "name": "\u6c5f\u82cf",
#                     "value": 53179
#                 },
#                 {
#                     "name": "\u6c5f\u897f",
#                     "val
